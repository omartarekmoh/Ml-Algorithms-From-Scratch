# %% [markdown]
# <a href="https://colab.research.google.com/github/omartarekmoh/Ml-Algorithms-From-Scratch/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Linear Regression:
# W * x + b

# %%
# Gradient Descent
# W = W - alpha * dw
# b = b - alpha * db

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #**Linear Regression**

# %%
class LinearRegression():

  def __init__(self, learning_rate = 0.1, epochs = 500):
    self.learning_rate = learning_rate
    self.epochs = epochs
    self.vdw = 0
    self.vdb = 0

  def fit(self, X, Y):
    # number of training examples and number of features
    self.m, self.n = X.shape # m = number of training examples, n = number of features
    # intialize weights
    self.intialize_weights()
    self.X = X
    self.Y = Y

    # Make the training through number of epochs
    for i in range(self.epochs):
      y_pred = self.predict(self.X)

      # Calculate Cost And Print it
      cost = self.cost_function(y_pred, self.Y)
      print(f"Epoch {i+1}/{self.epochs}, Cost: {cost}")

      # Update Weights
      self.update_weights()


  def update_weights(self, beta = 0.9):
    y_pred = self.predict(self.X)

    # Calculate Gradients
    dw = - (2 * self.X.T).dot(self.Y - y_pred) / self.m
    db = -2 * np.sum(self.Y - y_pred, dtype=np.float64) / self.m

    # Calculate Momentum
    self.vdw = beta * self.vdw + (1 - beta) * dw
    self.vdb = beta * self.vdb + (1 - beta) * db

    # Update the weights and bias with momentum
    self.w = self.w - self.learning_rate * self.vdw
    self.b = self.b - self.learning_rate * self.vdb

  def predict(self, X):
    # predict data W * x + b
    return X.dot(self.w) + self.b

  def intialize_weights(self):
    # Intialize weights with Xavier intialization although it's not necessary I could put the weights 0
    self.w = np.random.rand(self.n) * np.sqrt(1 / self.n)
    self.b = np.random.rand()

  def cost_function(self, y_pred, y_true):
    # Calculate RMSE
    mse = np.mean((y_pred - y_true) ** 2)
    rmse = np.sqrt(mse)
    return rmse

# %%
lr = LinearRegression()

# %%
df = pd.read_csv("salary_data.csv")

# %%
X = df.iloc[:, :-1].to_numpy()
y = df.iloc[:, -1].to_numpy()

# %%
lr.fit(X, y)
# Out:
# Epoch 1/500, Cost: 80640.68367057691
# Epoch 2/500, Cost: 24402.26359931332
# Epoch 3/500, Cost: 48813.13146362656
# Epoch 4/500, Cost: 74901.87627164194
# Epoch 5/500, Cost: 45140.28068087686
# Epoch 6/500, Cost: 19834.26183587609
# Epoch 7/500, Cost: 58809.82219695049
# Epoch 8/500, Cost: 54024.539823833955
# Epoch 9/500, Cost: 14780.861768570092
# Epoch 10/500, Cost: 38008.42590002688
# Epoch 11/500, Cost: 52075.688394080076
# Epoch 12/500, Cost: 28574.211028988044
# Epoch 13/500, Cost: 18133.175913838313
# Epoch 14/500, Cost: 42489.42134501435
# Epoch 15/500, Cost: 35964.83346001395
# Epoch 16/500, Cost: 10007.040145761217
# Epoch 17/500, Cost: 29028.40735953663
# Epoch 18/500, Cost: 35981.63656483781
# Epoch 19/500, Cost: 18050.762174094918
# Epoch 20/500, Cost: 15528.651573898806
# Epoch 21/500, Cost: 30465.777695913675
# Epoch 22/500, Cost: 23843.51540279582
# Epoch 23/500, Cost: 7862.462448610902
# Epoch 24/500, Cost: 21890.501336787962
# ...

# %%
plt.scatter(X, y)
plt.plot(X, lr.predict(X))

# %%
df = pd.read_csv("Walmart_sales.csv")

# %%
y = df.iloc[:, 2].to_numpy()

# %%
X = df.iloc[:, 4:].to_numpy()

# %%
lr = LinearRegression(0.001, 200)

# %%
lr.fit(X, y)
# Out:
# Epoch 1/200, Cost: 1189329.8878222355
# Epoch 2/200, Cost: 6056923.135006082
# Epoch 3/200, Cost: 29445361.83659047
# Epoch 4/200, Cost: 142879196.7166975
# Epoch 5/200, Cost: 693263233.6912876
# Epoch 6/200, Cost: 3363774060.110729
# Epoch 7/200, Cost: 16321326814.38594
# Epoch 8/200, Cost: 79192509518.01022
# Epoch 9/200, Cost: 384249003512.22675
# Epoch 10/200, Cost: 1864409874112.7498
# Epoch 11/200, Cost: 9046280268570.236
# Epoch 12/200, Cost: 43893345467540.6
# Epoch 13/200, Cost: 212974362846860.25
# Epoch 14/200, Cost: 1033370292168061.9
# Epoch 15/200, Cost: 5014003312235983.0
# Epoch 16/200, Cost: 2.4328383935218376e+16
# Epoch 17/200, Cost: 1.180434531136056e+17
# Epoch 18/200, Cost: 5.7275719012360826e+17
# Epoch 19/200, Cost: 2.77906813283896e+18
# Epoch 20/200, Cost: 1.3484282380277506e+19
# Epoch 21/200, Cost: 6.542692104684673e+19
# Epoch 22/200, Cost: 3.1745716063699173e+20
# Epoch 23/200, Cost: 1.540329993024452e+21
# Epoch 24/200, Cost: 7.473816254923807e+21
# ...
